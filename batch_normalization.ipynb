# %%
import argparse
import os
import shutil
import time

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data

import datasets
import models as models

from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3(a) PlainNet 8

# %% [markdown]
# ### Train PlainNet8

# %%
! python main.py -a plainnet8 2>&1 | tee log_plain8.txt

# %% [markdown]
# ### Load trained model

# %%
model = models.__dict__['plainnet8'](16,10)

# %%
checkpoint = torch.load('checkpoint_plain8.pth.tar')
state_dict = checkpoint['state_dict']

# %%
from collections import OrderedDict
new_state_dict = OrderedDict()
for k, v in state_dict.items():
    name = k[7:] # remove 'module.' of dataparallel
    new_state_dict[name]=v

model.load_state_dict(new_state_dict)

# %% [markdown]
# ### Find 1,3,5,7 layer

# %%
model.conv1 # layer 1 before BN
# Out:
# Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)

# %%
model.layer1[0].conv2 # layer 3 before BN
# Out:
# Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)

# %%
model.layer2[0].conv2 # layer 5 before BN
# Out:
# Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)

# %%
model.layer3[0].conv2 # layer 7 before BN
# Out:
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)

# %% [markdown]
# ### Create first 10 test data

# %%
test_loader = torch.utils.data.DataLoader(
            datasets.CIFAR10(
                root='./cifar10/test', train=False, download=True,
                transform=transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                ])),
            batch_size=10, shuffle=False)
# Out:
# Files already downloaded and verified

# %%
inputs, labels = next(iter(test_loader))
inputs, labels = Variable(inputs), Variable(labels)

# %% [markdown]
# ### Using hook to record hidden layer output

# %%
class Hook():
    '''
    A simple hook class that returns the input and output of a layer during forward/backward pass
    '''
    def __init__(self, module, backward=False):
        if backward==False:
            self.hook = module.register_forward_hook(self.hook_fn)
        else:
            self.hook = module.register_backward_hook(self.hook_fn)
    def hook_fn(self, module, input, output):
        self.input = input
        self.output = output
    def close(self):
        self.hook.remove()

# %%
hook1 = Hook(model.conv1) # register layer 1 on hook
hook3 = Hook(model.layer1[0].conv2) # register layer 3 on hook
hook5 = Hook(model.layer2[0].conv2) # register layer 5 on hook
hook7 = Hook(model.layer3[0].conv2) # register layer 7 on hook
out = model(inputs) # forward 10 test data

# %%
output1 = hook1.output.data.numpy()
output3 = hook3.output.data.numpy()
output5 = hook5.output.data.numpy()
output7 = hook7.output.data.numpy()

# %%
h1 = output1.flatten()
h3 = output3.flatten()
h5 = output5.flatten()
h7 = output7.flatten()

# %%
plt.hist(h1,bins='auto')  
plt.title("Histogram of the hidden layer outputs of layer 1")
plt.show()

# %%
plt.hist(h3,bins='auto')  
plt.title("Histogram of the hidden layer outputs of layer 3")
plt.show()

# %%
plt.hist(h5,bins='auto')  
plt.title("Histogram of the hidden layer outputs of layer 5")
plt.show()

# %%
plt.hist(h7,bins='auto')  
plt.title("Histogram of the hidden layer outputs of layer 7")
plt.show()

# %% [markdown]
# ### Normalize

# %%
def norm_BN(x, mean, var):
    '''
    x: input of BN, size 10*16*32*32
    mean: average running_mean of BN
    var: average running_var of BN, std is its square root
    '''
    norm = (x - mean) / np.sqrt(var)
    return norm

# %%
mean1 = np.mean(model.bn1.running_mean.numpy()) 
var1 = np.mean(model.bn1.running_var.numpy()) 

mean3 = np.mean(model.layer1[0].bn2.running_mean.numpy()) 
var3 = np.mean(model.layer1[0].bn2.running_var.numpy())

mean5 = np.mean(model.layer2[0].bn2.running_mean.numpy())
var5 = np.mean(model.layer2[0].bn2.running_var.numpy())

mean7 = np.mean(model.layer3[0].bn2.running_mean.numpy())
var7 = np.mean(model.layer3[0].bn2.running_var.numpy())

# %%
h1_normed = norm_BN(h1, mean1, var1)
h3_normed = norm_BN(h3, mean3, var3)
h5_normed = norm_BN(h5, mean5, var5)
h7_normed = norm_BN(h7, mean7, var7)

# %%
plt.hist(h1_normed, bins='auto')  
plt.title("Histogram of the normalized hidden layer outputs of layer 1")
plt.show()

# %%
plt.hist(h3_normed, bins='auto')  
plt.title("Histogram of the normalized hidden layer outputs of layer 3")
plt.show()

# %%
plt.hist(h5_normed, bins='auto')  
plt.title("Histogram of the normalized hidden layer outputs of layer 5")
plt.show()

# %%
plt.hist(h7_normed, bins='auto')  
plt.title("Histogram of the normalized hidden layer outputs of layer 7")
plt.show()

# %% [markdown]
# ### Comparison

# %%
png = plt.imread('histogram.png')
plt.figure(figsize = (30,15))
plt.imshow(png, interpolation='nearest')

# %% [markdown]
# We can see that after normalization, the mean of outputs from each layer is around 0 with a std around 1, i.e., all the layer output has almost same distribution. This will makes the cost function more spherical and the learning process more stable.

# %% [markdown]
# ## 3(b) PlainNoBnNet8

# %%
def plot(logfile):
    with open(logfile, 'r') as f:
        line = f.readlines()
        
    train_error = []
    for i in range(len(line)):
        if 'Training Prec' in line[i]:
            line_word = line[i].split()
            train_error.append(100.0 - float(line_word[3]))
    
    test_error = []
    for i in range(len(line)):
        if 'Testing Prec' in line[i]:
            line_word = line[i].split()
            test_error.append(100.0 - float(line_word[3]))
            
    val_loss = []
    for i in range(len(line)):
        if 'Test:' in line[i]:
            line_word = line[i].split()
            val_loss.append(float(line_word[6]))
            

    train_loss = []
    for i in range(len(line)):
        if 'Epoch' in line[i]:
            line_word = line[i].split()
            train_loss.append(float(line_word[11]))
            
    x = np.linspace(1,len(train_error),len(train_error))
    plt.plot(x,train_error,label='training error')
    plt.plot(x,test_error,label='testing error')
    plt.xlabel('epoch')
    plt.ylabel('error(%)')
    plt.legend()
            
    return train_error, test_error, train_loss, val_loss

# %% [markdown]
# ### Plot of error curves of PlainNet 8

# %%
train, test, _, _ = plot('log_plain8.txt')

# %% [markdown]
# ### Train PlainNoBnNet8

# %%
! python main.py -a plainnet8 2>&1 | tee log_plain8_noBN.txt

# %%
train_noBN, test_noBN, _, _ = plot('log_plain8_noBN.txt')

# %% [markdown]
# ### Comparison

# %%
x = np.linspace(1,80,80)
plt.plot(x,train,label = 'training error of Plain8')
plt.plot(x,test,label = 'test error of Plain8')
plt.plot(x,train_noBN,label = 'training error of Plain8_noBN')
plt.plot(x,test_noBN,label = 'test error of Plain8_noBN')
plt.xlabel('epoch')
plt.ylabel('error')
plt.legend()

# %% [markdown]
# - From the error curve above, we can see that both training error and test error of PlainNoBnNet8 are higher than those in PlainNet8 with batch normalization.
# - Final test error of PlainNet 8 is 13.68%, final test error for PlainNoBnNet8 is 15.93%. And this is only 8 layers.
# - We can see that PlainNet8's error starts to decrease a lot since epoch 5, however, large decreasing starts at about epoch 10 for PlainNoBnNet8. BN actually speeds up the optimization process.
# - Thus, batch normalization indeed makes the learning more stable and produces a better result.

# %% [markdown]
# ## 3(c) PlainNoBnNet20

# %% [markdown]
# ### Train PlainNoBnNet20

# %%
! python main.py -a plainnet20 2>&1 | tee log_plain20_noBN.txt
# Out:
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# CIFAR-10 training data size: 50000
# Files already downloaded and verified
# CIFAR-10 testing data size: 10000
# => creating model 'plainnet20'
# Epoch: [0/80][0/250]	LR: 0.1	Time 1.960 (1.960)	Data 0.147 (0.147)	Loss 2.3051 (2.3051)	Prec@1 10.000 (10.000)
# Epoch: [0/80][100/250]	LR: 0.1	Time 0.063 (0.061)	Data 0.051 (0.031)	Loss 2.2924 (2.3040)	Prec@1 11.000 (9.921)
# Epoch: [0/80][200/250]	LR: 0.1	Time 0.036 (0.048)	Data 0.025 (0.028)	Loss 2.3097 (2.3031)	Prec@1 9.000 (10.177)
#  * Training Prec@1 10.160
# Test: [0/50]	Time 0.214 (0.214)	Loss 2.3061 (2.3061)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [1/80][0/250]	LR: 0.1	Time 0.233 (0.233)	Data 0.220 (0.220)	Loss 2.3003 (2.3003)	Prec@1 13.000 (13.000)
# Epoch: [1/80][100/250]	LR: 0.1	Time 0.031 (0.039)	Data 0.021 (0.028)	Loss 2.2994 (2.3038)	Prec@1 13.000 (10.054)
# Epoch: [1/80][200/250]	LR: 0.1	Time 0.038 (0.037)	Data 0.027 (0.027)	Loss 2.3031 (2.3039)	Prec@1 10.000 (10.025)
#  * Training Prec@1 10.036
# Test: [0/50]	Time 0.130 (0.130)	Loss 2.3035 (2.3035)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [2/80][0/250]	LR: 0.1	Time 0.258 (0.258)	Data 0.247 (0.247)	Loss 2.2988 (2.2988)	Prec@1 15.000 (15.000)
# Epoch: [2/80][100/250]	LR: 0.1	Time 0.033 (0.041)	Data 0.023 (0.031)	Loss 2.3050 (2.3039)	Prec@1 7.000 (9.837)
# Epoch: [2/80][200/250]	LR: 0.1	Time 0.034 (0.038)	Data 0.025 (0.028)	Loss 2.3004 (2.3037)	Prec@1 12.000 (9.918)
#  * Training Prec@1 9.964
# Test: [0/50]	Time 0.139 (0.139)	Loss 2.3093 (2.3093)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [3/80][0/250]	LR: 0.1	Time 0.239 (0.239)	Data 0.225 (0.225)	Loss 2.3024 (2.3024)	Prec@1 10.000 (10.000)
# Epoch: [3/80][100/250]	LR: 0.1	Time 0.030 (0.036)	Data 0.021 (0.026)	Loss 2.3038 (2.3032)	Prec@1 13.000 (9.955)
# Epoch: [3/80][200/250]	LR: 0.1	Time 0.032 (0.036)	Data 0.022 (0.026)	Loss 2.3036 (2.3038)	Prec@1 11.000 (9.784)
#  * Training Prec@1 9.778
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.3015 (2.3015)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [4/80][0/250]	LR: 0.1	Time 0.158 (0.158)	Data 0.147 (0.147)	Loss 2.3018 (2.3018)	Prec@1 12.000 (12.000)
# Epoch: [4/80][100/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3022 (2.3040)	Prec@1 8.000 (9.728)
# Epoch: [4/80][200/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.022 (0.023)	Loss 2.3085 (2.3039)	Prec@1 12.000 (9.833)
#  * Training Prec@1 9.850
# Test: [0/50]	Time 0.099 (0.099)	Loss 2.3057 (2.3057)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [5/80][0/250]	LR: 0.1	Time 0.221 (0.221)	Data 0.208 (0.208)	Loss 2.3026 (2.3026)	Prec@1 12.000 (12.000)
# Epoch: [5/80][100/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.024 (0.025)	Loss 2.3042 (2.3039)	Prec@1 12.000 (9.916)
# Epoch: [5/80][200/250]	LR: 0.1	Time 0.032 (0.034)	Data 0.023 (0.024)	Loss 2.3006 (2.3037)	Prec@1 14.500 (9.871)
#  * Training Prec@1 9.916
# Test: [0/50]	Time 0.105 (0.105)	Loss 2.3012 (2.3012)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [6/80][0/250]	LR: 0.1	Time 0.267 (0.267)	Data 0.251 (0.251)	Loss 2.3056 (2.3056)	Prec@1 9.000 (9.000)
# Epoch: [6/80][100/250]	LR: 0.1	Time 0.032 (0.036)	Data 0.023 (0.026)	Loss 2.3035 (2.3035)	Prec@1 10.500 (9.703)
# Epoch: [6/80][200/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.024 (0.024)	Loss 2.3002 (2.3037)	Prec@1 11.000 (9.791)
#  * Training Prec@1 9.766
# Test: [0/50]	Time 0.102 (0.102)	Loss 2.2999 (2.2999)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [7/80][0/250]	LR: 0.1	Time 0.169 (0.169)	Data 0.155 (0.155)	Loss 2.3016 (2.3016)	Prec@1 6.500 (6.500)
# Epoch: [7/80][100/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.024 (0.024)	Loss 2.3016 (2.3042)	Prec@1 10.000 (9.965)
# Epoch: [7/80][200/250]	LR: 0.1	Time 0.035 (0.036)	Data 0.025 (0.026)	Loss 2.3034 (2.3042)	Prec@1 8.500 (9.786)
#  * Training Prec@1 9.796
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.3064 (2.3064)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [8/80][0/250]	LR: 0.1	Time 0.170 (0.170)	Data 0.157 (0.157)	Loss 2.3024 (2.3024)	Prec@1 8.000 (8.000)
# Epoch: [8/80][100/250]	LR: 0.1	Time 0.034 (0.036)	Data 0.024 (0.025)	Loss 2.3069 (2.3037)	Prec@1 8.500 (10.020)
# Epoch: [8/80][200/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.024 (0.024)	Loss 2.3039 (2.3037)	Prec@1 10.000 (10.077)
#  * Training Prec@1 10.188
# Test: [0/50]	Time 0.138 (0.138)	Loss 2.3023 (2.3023)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [9/80][0/250]	LR: 0.1	Time 0.261 (0.261)	Data 0.245 (0.245)	Loss 2.3019 (2.3019)	Prec@1 10.500 (10.500)
# Epoch: [9/80][100/250]	LR: 0.1	Time 0.033 (0.036)	Data 0.024 (0.026)	Loss 2.3059 (2.3039)	Prec@1 9.500 (9.757)
# Epoch: [9/80][200/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3030 (2.3039)	Prec@1 13.000 (9.838)
#  * Training Prec@1 9.790
# Test: [0/50]	Time 0.131 (0.131)	Loss 2.3019 (2.3019)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [10/80][0/250]	LR: 0.1	Time 0.268 (0.268)	Data 0.252 (0.252)	Loss 2.3034 (2.3034)	Prec@1 8.000 (8.000)
# Epoch: [10/80][100/250]	LR: 0.1	Time 0.032 (0.036)	Data 0.023 (0.026)	Loss 2.3019 (2.3038)	Prec@1 10.000 (9.931)
# Epoch: [10/80][200/250]	LR: 0.1	Time 0.032 (0.035)	Data 0.023 (0.024)	Loss 2.3007 (2.3037)	Prec@1 12.000 (9.968)
#  * Training Prec@1 9.926
# Test: [0/50]	Time 0.104 (0.104)	Loss 2.3023 (2.3023)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [11/80][0/250]	LR: 0.1	Time 0.276 (0.276)	Data 0.258 (0.258)	Loss 2.3039 (2.3039)	Prec@1 6.500 (6.500)
# Epoch: [11/80][100/250]	LR: 0.1	Time 0.034 (0.037)	Data 0.024 (0.026)	Loss 2.2990 (2.3039)	Prec@1 13.500 (10.005)
# Epoch: [11/80][200/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.024)	Loss 2.3070 (2.3041)	Prec@1 7.000 (9.965)
#  * Training Prec@1 9.952
# Test: [0/50]	Time 0.107 (0.107)	Loss 2.3028 (2.3028)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [12/80][0/250]	LR: 0.1	Time 0.159 (0.159)	Data 0.145 (0.145)	Loss 2.3056 (2.3056)	Prec@1 7.500 (7.500)
# Epoch: [12/80][100/250]	LR: 0.1	Time 0.040 (0.036)	Data 0.029 (0.026)	Loss 2.3016 (2.3037)	Prec@1 8.500 (9.916)
# Epoch: [12/80][200/250]	LR: 0.1	Time 0.032 (0.037)	Data 0.022 (0.027)	Loss 2.3064 (2.3039)	Prec@1 8.500 (9.779)
#  * Training Prec@1 9.758
# Test: [0/50]	Time 0.134 (0.134)	Loss 2.3016 (2.3016)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [13/80][0/250]	LR: 0.1	Time 0.157 (0.157)	Data 0.144 (0.144)	Loss 2.3026 (2.3026)	Prec@1 10.000 (10.000)
# Epoch: [13/80][100/250]	LR: 0.1	Time 0.036 (0.035)	Data 0.026 (0.025)	Loss 2.3081 (2.3040)	Prec@1 8.500 (9.941)
# Epoch: [13/80][200/250]	LR: 0.1	Time 0.036 (0.034)	Data 0.025 (0.024)	Loss 2.3062 (2.3038)	Prec@1 8.000 (9.846)
#  * Training Prec@1 9.934
# Test: [0/50]	Time 0.111 (0.111)	Loss 2.3045 (2.3045)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [14/80][0/250]	LR: 0.1	Time 0.264 (0.264)	Data 0.250 (0.250)	Loss 2.2987 (2.2987)	Prec@1 14.500 (14.500)
# Epoch: [14/80][100/250]	LR: 0.1	Time 0.032 (0.036)	Data 0.022 (0.025)	Loss 2.3001 (2.3037)	Prec@1 13.000 (9.787)
# Epoch: [14/80][200/250]	LR: 0.1	Time 0.034 (0.034)	Data 0.023 (0.024)	Loss 2.3029 (2.3037)	Prec@1 11.500 (9.756)
#  * Training Prec@1 9.760
# Test: [0/50]	Time 0.101 (0.101)	Loss 2.3007 (2.3007)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [15/80][0/250]	LR: 0.1	Time 0.277 (0.277)	Data 0.264 (0.264)	Loss 2.2997 (2.2997)	Prec@1 11.500 (11.500)
# Epoch: [15/80][100/250]	LR: 0.1	Time 0.031 (0.036)	Data 0.021 (0.026)	Loss 2.3043 (2.3040)	Prec@1 12.000 (9.683)
# Epoch: [15/80][200/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.022 (0.024)	Loss 2.3039 (2.3040)	Prec@1 8.500 (9.851)
#  * Training Prec@1 9.854
# Test: [0/50]	Time 0.106 (0.106)	Loss 2.3036 (2.3036)	Prec@1 10.000 (10.000)
#  * Testing Prec@1 10.000
# Epoch: [16/80][0/250]	LR: 0.1	Time 0.152 (0.152)	Data 0.136 (0.136)	Loss 2.3033 (2.3033)	Prec@1 12.000 (12.000)
# Epoch: [16/80][100/250]	LR: 0.1	Time 0.032 (0.035)	Data 0.022 (0.024)	Loss 2.3057 (2.3039)	Prec@1 8.500 (9.500)
# Epoch: [16/80][200/250]	LR: 0.1	Time 0.034 (0.035)	Data 0.024 (0.025)	Loss 2.3140 (2.3040)	Prec@1 5.500 (9.719)
#  * Training Prec@1 9.900
# Test: [0/50]	Time 0.143 (0.143)	Loss 2.2995 (2.2995)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [17/80][0/250]	LR: 0.1	Time 0.280 (0.280)	Data 0.262 (0.262)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
# Epoch: [17/80][100/250]	LR: 0.1	Time 0.035 (0.039)	Data 0.025 (0.029)	Loss 2.3095 (2.3034)	Prec@1 10.000 (10.386)
# Epoch: [17/80][200/250]	LR: 0.1	Time 0.033 (0.036)	Data 0.024 (0.026)	Loss 2.3035 (2.3035)	Prec@1 11.000 (10.147)
#  * Training Prec@1 10.110
# Test: [0/50]	Time 0.150 (0.150)	Loss 2.3017 (2.3017)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [18/80][0/250]	LR: 0.1	Time 0.237 (0.237)	Data 0.226 (0.226)	Loss 2.3057 (2.3057)	Prec@1 8.500 (8.500)
# Epoch: [18/80][100/250]	LR: 0.1	Time 0.034 (0.035)	Data 0.024 (0.024)	Loss 2.3002 (2.3038)	Prec@1 9.500 (9.738)
# Epoch: [18/80][200/250]	LR: 0.1	Time 0.034 (0.035)	Data 0.023 (0.025)	Loss 2.3020 (2.3037)	Prec@1 9.000 (9.953)
#  * Training Prec@1 9.976
# Test: [0/50]	Time 0.130 (0.130)	Loss 2.3044 (2.3044)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [19/80][0/250]	LR: 0.1	Time 0.272 (0.272)	Data 0.258 (0.258)	Loss 2.3065 (2.3065)	Prec@1 9.000 (9.000)
# Epoch: [19/80][100/250]	LR: 0.1	Time 0.037 (0.037)	Data 0.025 (0.027)	Loss 2.3001 (2.3038)	Prec@1 10.000 (10.064)
# Epoch: [19/80][200/250]	LR: 0.1	Time 0.030 (0.035)	Data 0.020 (0.025)	Loss 2.3042 (2.3039)	Prec@1 10.000 (9.945)
#  * Training Prec@1 9.914
# Test: [0/50]	Time 0.100 (0.100)	Loss 2.3043 (2.3043)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [20/80][0/250]	LR: 0.1	Time 0.139 (0.139)	Data 0.125 (0.125)	Loss 2.3031 (2.3031)	Prec@1 6.500 (6.500)
# Epoch: [20/80][100/250]	LR: 0.1	Time 0.034 (0.038)	Data 0.023 (0.028)	Loss 2.3074 (2.3035)	Prec@1 8.000 (9.812)
# Epoch: [20/80][200/250]	LR: 0.1	Time 0.029 (0.036)	Data 0.020 (0.025)	Loss 2.3086 (2.3035)	Prec@1 7.500 (9.898)
#  * Training Prec@1 9.926
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.3108 (2.3108)	Prec@1 7.500 (7.500)
#  * Testing Prec@1 10.000
# Epoch: [21/80][0/250]	LR: 0.1	Time 0.276 (0.276)	Data 0.262 (0.262)	Loss 2.3085 (2.3085)	Prec@1 9.500 (9.500)
# Epoch: [21/80][100/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3018 (2.3042)	Prec@1 10.000 (9.629)
# Epoch: [21/80][200/250]	LR: 0.1	Time 0.038 (0.034)	Data 0.028 (0.024)	Loss 2.3037 (2.3038)	Prec@1 9.000 (9.973)
#  * Training Prec@1 9.962
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.3057 (2.3057)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [22/80][0/250]	LR: 0.1	Time 0.167 (0.167)	Data 0.154 (0.154)	Loss 2.3073 (2.3073)	Prec@1 8.500 (8.500)
# Epoch: [22/80][100/250]	LR: 0.1	Time 0.035 (0.034)	Data 0.023 (0.024)	Loss 2.3076 (2.3038)	Prec@1 11.500 (10.089)
# Epoch: [22/80][200/250]	LR: 0.1	Time 0.032 (0.034)	Data 0.022 (0.024)	Loss 2.3056 (2.3040)	Prec@1 8.000 (9.955)
#  * Training Prec@1 9.954
# Test: [0/50]	Time 0.099 (0.099)	Loss 2.3006 (2.3006)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [23/80][0/250]	LR: 0.1	Time 0.232 (0.232)	Data 0.218 (0.218)	Loss 2.3017 (2.3017)	Prec@1 15.500 (15.500)
# Epoch: [23/80][100/250]	LR: 0.1	Time 0.031 (0.035)	Data 0.021 (0.025)	Loss 2.3034 (2.3039)	Prec@1 9.000 (9.995)
# Epoch: [23/80][200/250]	LR: 0.1	Time 0.035 (0.034)	Data 0.022 (0.024)	Loss 2.3016 (2.3038)	Prec@1 10.000 (9.843)
#  * Training Prec@1 9.818
# Test: [0/50]	Time 0.098 (0.098)	Loss 2.3021 (2.3021)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [24/80][0/250]	LR: 0.1	Time 0.259 (0.259)	Data 0.243 (0.243)	Loss 2.3037 (2.3037)	Prec@1 9.000 (9.000)
# Epoch: [24/80][100/250]	LR: 0.1	Time 0.032 (0.035)	Data 0.022 (0.025)	Loss 2.3024 (2.3037)	Prec@1 9.500 (9.772)
# Epoch: [24/80][200/250]	LR: 0.1	Time 0.032 (0.034)	Data 0.022 (0.024)	Loss 2.3089 (2.3036)	Prec@1 10.000 (9.898)
#  * Training Prec@1 9.852
# Test: [0/50]	Time 0.095 (0.095)	Loss 2.3033 (2.3033)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [25/80][0/250]	LR: 0.1	Time 0.298 (0.298)	Data 0.281 (0.281)	Loss 2.3042 (2.3042)	Prec@1 10.500 (10.500)
# Epoch: [25/80][100/250]	LR: 0.1	Time 0.033 (0.038)	Data 0.023 (0.028)	Loss 2.2971 (2.3035)	Prec@1 14.500 (10.267)
# Epoch: [25/80][200/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3044 (2.3037)	Prec@1 10.500 (10.154)
#  * Training Prec@1 10.112
# Test: [0/50]	Time 0.132 (0.132)	Loss 2.2949 (2.2949)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [26/80][0/250]	LR: 0.1	Time 0.288 (0.288)	Data 0.271 (0.271)	Loss 2.3041 (2.3041)	Prec@1 10.500 (10.500)
# Epoch: [26/80][100/250]	LR: 0.1	Time 0.032 (0.036)	Data 0.022 (0.026)	Loss 2.3014 (2.3035)	Prec@1 12.500 (10.292)
# Epoch: [26/80][200/250]	LR: 0.1	Time 0.043 (0.037)	Data 0.033 (0.026)	Loss 2.3097 (2.3037)	Prec@1 5.500 (10.119)
#  * Training Prec@1 10.126
# Test: [0/50]	Time 0.133 (0.133)	Loss 2.3049 (2.3049)	Prec@1 7.500 (7.500)
#  * Testing Prec@1 10.000
# Epoch: [27/80][0/250]	LR: 0.1	Time 0.210 (0.210)	Data 0.197 (0.197)	Loss 2.3056 (2.3056)	Prec@1 10.000 (10.000)
# Epoch: [27/80][100/250]	LR: 0.1	Time 0.032 (0.038)	Data 0.022 (0.028)	Loss 2.2991 (2.3040)	Prec@1 11.000 (9.832)
# Epoch: [27/80][200/250]	LR: 0.1	Time 0.033 (0.036)	Data 0.024 (0.026)	Loss 2.3027 (2.3039)	Prec@1 11.000 (9.853)
#  * Training Prec@1 9.832
# Test: [0/50]	Time 0.125 (0.125)	Loss 2.3049 (2.3049)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [28/80][0/250]	LR: 0.1	Time 0.237 (0.237)	Data 0.223 (0.223)	Loss 2.3049 (2.3049)	Prec@1 9.000 (9.000)
# Epoch: [28/80][100/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.026)	Loss 2.3060 (2.3039)	Prec@1 6.500 (10.030)
# Epoch: [28/80][200/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3100 (2.3038)	Prec@1 11.000 (10.114)
#  * Training Prec@1 10.020
# Test: [0/50]	Time 0.098 (0.098)	Loss 2.3109 (2.3109)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [29/80][0/250]	LR: 0.1	Time 0.161 (0.161)	Data 0.147 (0.147)	Loss 2.3079 (2.3079)	Prec@1 12.500 (12.500)
# Epoch: [29/80][100/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.022 (0.024)	Loss 2.3042 (2.3042)	Prec@1 8.000 (9.842)
# Epoch: [29/80][200/250]	LR: 0.1	Time 0.033 (0.034)	Data 0.024 (0.024)	Loss 2.3022 (2.3040)	Prec@1 11.500 (9.868)
#  * Training Prec@1 9.890
# Test: [0/50]	Time 0.097 (0.097)	Loss 2.3054 (2.3054)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [30/80][0/250]	LR: 0.1	Time 0.269 (0.269)	Data 0.254 (0.254)	Loss 2.3007 (2.3007)	Prec@1 8.500 (8.500)
# Epoch: [30/80][100/250]	LR: 0.1	Time 0.033 (0.036)	Data 0.023 (0.026)	Loss 2.3031 (2.3038)	Prec@1 10.500 (9.847)
# Epoch: [30/80][200/250]	LR: 0.1	Time 0.034 (0.035)	Data 0.024 (0.025)	Loss 2.3067 (2.3037)	Prec@1 10.000 (9.746)
#  * Training Prec@1 9.840
# Test: [0/50]	Time 0.133 (0.133)	Loss 2.3037 (2.3037)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [31/80][0/250]	LR: 0.1	Time 0.236 (0.236)	Data 0.225 (0.225)	Loss 2.3044 (2.3044)	Prec@1 11.500 (11.500)
# Epoch: [31/80][100/250]	LR: 0.1	Time 0.034 (0.041)	Data 0.023 (0.031)	Loss 2.3049 (2.3039)	Prec@1 9.000 (9.931)
# Epoch: [31/80][200/250]	LR: 0.1	Time 0.033 (0.037)	Data 0.023 (0.027)	Loss 2.2995 (2.3039)	Prec@1 12.000 (9.968)
#  * Training Prec@1 10.016
# Test: [0/50]	Time 0.104 (0.104)	Loss 2.2977 (2.2977)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [32/80][0/250]	LR: 0.1	Time 0.241 (0.241)	Data 0.227 (0.227)	Loss 2.3029 (2.3029)	Prec@1 10.000 (10.000)
# Epoch: [32/80][100/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3007 (2.3040)	Prec@1 12.500 (10.124)
# Epoch: [32/80][200/250]	LR: 0.1	Time 0.032 (0.036)	Data 0.022 (0.026)	Loss 2.3068 (2.3039)	Prec@1 7.500 (10.057)
#  * Training Prec@1 10.140
# Test: [0/50]	Time 0.124 (0.124)	Loss 2.3067 (2.3067)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [33/80][0/250]	LR: 0.1	Time 0.278 (0.278)	Data 0.263 (0.263)	Loss 2.3053 (2.3053)	Prec@1 8.500 (8.500)
# Epoch: [33/80][100/250]	LR: 0.1	Time 0.034 (0.037)	Data 0.024 (0.027)	Loss 2.3038 (2.3037)	Prec@1 10.000 (10.421)
# Epoch: [33/80][200/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3055 (2.3037)	Prec@1 6.000 (10.057)
#  * Training Prec@1 10.048
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.2989 (2.2989)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [34/80][0/250]	LR: 0.1	Time 0.196 (0.196)	Data 0.180 (0.180)	Loss 2.3083 (2.3083)	Prec@1 8.000 (8.000)
# Epoch: [34/80][100/250]	LR: 0.1	Time 0.033 (0.044)	Data 0.024 (0.033)	Loss 2.3015 (2.3038)	Prec@1 5.500 (10.153)
# Epoch: [34/80][200/250]	LR: 0.1	Time 0.034 (0.039)	Data 0.024 (0.028)	Loss 2.3001 (2.3037)	Prec@1 11.500 (10.162)
#  * Training Prec@1 9.986
# Test: [0/50]	Time 0.140 (0.140)	Loss 2.3020 (2.3020)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [35/80][0/250]	LR: 0.1	Time 0.243 (0.243)	Data 0.230 (0.230)	Loss 2.3065 (2.3065)	Prec@1 7.500 (7.500)
# Epoch: [35/80][100/250]	LR: 0.1	Time 0.036 (0.038)	Data 0.026 (0.028)	Loss 2.3036 (2.3039)	Prec@1 12.500 (9.698)
# Epoch: [35/80][200/250]	LR: 0.1	Time 0.033 (0.036)	Data 0.023 (0.026)	Loss 2.3036 (2.3039)	Prec@1 7.500 (9.853)
#  * Training Prec@1 9.956
# Test: [0/50]	Time 0.150 (0.150)	Loss 2.3015 (2.3015)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [36/80][0/250]	LR: 0.1	Time 0.229 (0.229)	Data 0.217 (0.217)	Loss 2.3022 (2.3022)	Prec@1 10.000 (10.000)
# Epoch: [36/80][100/250]	LR: 0.1	Time 0.031 (0.037)	Data 0.021 (0.027)	Loss 2.3031 (2.3039)	Prec@1 11.500 (9.772)
# Epoch: [36/80][200/250]	LR: 0.1	Time 0.045 (0.035)	Data 0.034 (0.025)	Loss 2.2994 (2.3037)	Prec@1 9.000 (9.896)
#  * Training Prec@1 9.928
# Test: [0/50]	Time 0.103 (0.103)	Loss 2.3003 (2.3003)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [37/80][0/250]	LR: 0.1	Time 0.222 (0.222)	Data 0.210 (0.210)	Loss 2.3014 (2.3014)	Prec@1 10.000 (10.000)
# Epoch: [37/80][100/250]	LR: 0.1	Time 0.035 (0.038)	Data 0.025 (0.029)	Loss 2.3048 (2.3037)	Prec@1 8.500 (9.876)
# Epoch: [37/80][200/250]	LR: 0.1	Time 0.034 (0.036)	Data 0.024 (0.027)	Loss 2.3050 (2.3036)	Prec@1 10.000 (9.930)
#  * Training Prec@1 9.972
# Test: [0/50]	Time 0.105 (0.105)	Loss 2.3104 (2.3104)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [38/80][0/250]	LR: 0.1	Time 0.162 (0.162)	Data 0.147 (0.147)	Loss 2.3001 (2.3001)	Prec@1 9.000 (9.000)
# Epoch: [38/80][100/250]	LR: 0.1	Time 0.035 (0.037)	Data 0.025 (0.027)	Loss 2.3000 (2.3037)	Prec@1 8.500 (9.634)
# Epoch: [38/80][200/250]	LR: 0.1	Time 0.033 (0.035)	Data 0.024 (0.025)	Loss 2.3046 (2.3038)	Prec@1 8.000 (9.813)
#  * Training Prec@1 9.810
# Test: [0/50]	Time 0.117 (0.117)	Loss 2.3032 (2.3032)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [39/80][0/250]	LR: 0.1	Time 0.262 (0.262)	Data 0.247 (0.247)	Loss 2.3000 (2.3000)	Prec@1 11.500 (11.500)
# Epoch: [39/80][100/250]	LR: 0.1	Time 0.036 (0.042)	Data 0.025 (0.031)	Loss 2.3045 (2.3037)	Prec@1 9.500 (9.926)
# Epoch: [39/80][200/250]	LR: 0.1	Time 0.037 (0.041)	Data 0.027 (0.030)	Loss 2.3027 (2.3037)	Prec@1 8.500 (10.052)
#  * Training Prec@1 10.054
# Test: [0/50]	Time 0.142 (0.142)	Loss 2.3033 (2.3033)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [40/80][0/250]	LR: 0.01	Time 0.234 (0.234)	Data 0.218 (0.218)	Loss 2.3089 (2.3089)	Prec@1 10.000 (10.000)
# Epoch: [40/80][100/250]	LR: 0.01	Time 0.035 (0.036)	Data 0.025 (0.026)	Loss 2.3037 (2.3029)	Prec@1 11.000 (10.168)
# Epoch: [40/80][200/250]	LR: 0.01	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3030 (2.3030)	Prec@1 6.500 (9.988)
#  * Training Prec@1 9.956
# Test: [0/50]	Time 0.112 (0.112)	Loss 2.3019 (2.3019)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [41/80][0/250]	LR: 0.01	Time 0.268 (0.268)	Data 0.253 (0.253)	Loss 2.3025 (2.3025)	Prec@1 9.500 (9.500)
# Epoch: [41/80][100/250]	LR: 0.01	Time 0.035 (0.043)	Data 0.025 (0.032)	Loss 2.3023 (2.3027)	Prec@1 9.500 (9.668)
# Epoch: [41/80][200/250]	LR: 0.01	Time 0.033 (0.039)	Data 0.024 (0.029)	Loss 2.3029 (2.3027)	Prec@1 8.500 (9.833)
#  * Training Prec@1 9.730
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.3025 (2.3025)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [42/80][0/250]	LR: 0.01	Time 0.245 (0.245)	Data 0.230 (0.230)	Loss 2.3026 (2.3026)	Prec@1 11.000 (11.000)
# Epoch: [42/80][100/250]	LR: 0.01	Time 0.035 (0.038)	Data 0.025 (0.027)	Loss 2.3040 (2.3027)	Prec@1 9.000 (10.040)
# Epoch: [42/80][200/250]	LR: 0.01	Time 0.035 (0.038)	Data 0.025 (0.027)	Loss 2.3032 (2.3027)	Prec@1 7.500 (9.985)
#  * Training Prec@1 9.970
# Test: [0/50]	Time 0.107 (0.107)	Loss 2.3038 (2.3038)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [43/80][0/250]	LR: 0.01	Time 0.173 (0.173)	Data 0.157 (0.157)	Loss 2.3016 (2.3016)	Prec@1 11.500 (11.500)
# Epoch: [43/80][100/250]	LR: 0.01	Time 0.039 (0.041)	Data 0.028 (0.030)	Loss 2.3033 (2.3027)	Prec@1 8.500 (9.886)
# Epoch: [43/80][200/250]	LR: 0.01	Time 0.037 (0.040)	Data 0.026 (0.030)	Loss 2.3033 (2.3028)	Prec@1 9.000 (9.848)
#  * Training Prec@1 9.810
# Test: [0/50]	Time 0.151 (0.151)	Loss 2.3032 (2.3032)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [44/80][0/250]	LR: 0.01	Time 0.234 (0.234)	Data 0.221 (0.221)	Loss 2.3018 (2.3018)	Prec@1 11.500 (11.500)
# Epoch: [44/80][100/250]	LR: 0.01	Time 0.041 (0.040)	Data 0.029 (0.030)	Loss 2.3021 (2.3026)	Prec@1 12.500 (10.089)
# Epoch: [44/80][200/250]	LR: 0.01	Time 0.034 (0.038)	Data 0.025 (0.028)	Loss 2.3024 (2.3027)	Prec@1 11.500 (9.990)
#  * Training Prec@1 9.912
# Test: [0/50]	Time 0.138 (0.138)	Loss 2.3030 (2.3030)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [45/80][0/250]	LR: 0.01	Time 0.248 (0.248)	Data 0.233 (0.233)	Loss 2.3020 (2.3020)	Prec@1 8.500 (8.500)
# Epoch: [45/80][100/250]	LR: 0.01	Time 0.032 (0.038)	Data 0.021 (0.028)	Loss 2.3046 (2.3027)	Prec@1 5.500 (9.842)
# Epoch: [45/80][200/250]	LR: 0.01	Time 0.034 (0.035)	Data 0.024 (0.025)	Loss 2.3036 (2.3028)	Prec@1 9.000 (9.761)
#  * Training Prec@1 9.670
# Test: [0/50]	Time 0.130 (0.130)	Loss 2.3017 (2.3017)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [46/80][0/250]	LR: 0.01	Time 0.127 (0.127)	Data 0.111 (0.111)	Loss 2.3020 (2.3020)	Prec@1 11.500 (11.500)
# Epoch: [46/80][100/250]	LR: 0.01	Time 0.033 (0.034)	Data 0.023 (0.023)	Loss 2.3033 (2.3027)	Prec@1 10.500 (10.134)
# Epoch: [46/80][200/250]	LR: 0.01	Time 0.034 (0.034)	Data 0.024 (0.024)	Loss 2.3028 (2.3027)	Prec@1 9.500 (9.968)
#  * Training Prec@1 9.974
# Test: [0/50]	Time 0.130 (0.130)	Loss 2.3017 (2.3017)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [47/80][0/250]	LR: 0.01	Time 0.148 (0.148)	Data 0.136 (0.136)	Loss 2.3021 (2.3021)	Prec@1 8.500 (8.500)
# Epoch: [47/80][100/250]	LR: 0.01	Time 0.034 (0.034)	Data 0.025 (0.024)	Loss 2.3035 (2.3028)	Prec@1 9.000 (9.876)
# Epoch: [47/80][200/250]	LR: 0.01	Time 0.032 (0.034)	Data 0.023 (0.024)	Loss 2.3018 (2.3028)	Prec@1 11.000 (9.883)
#  * Training Prec@1 9.720
# Test: [0/50]	Time 0.109 (0.109)	Loss 2.3027 (2.3027)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [48/80][0/250]	LR: 0.01	Time 0.167 (0.167)	Data 0.154 (0.154)	Loss 2.3030 (2.3030)	Prec@1 10.000 (10.000)
# Epoch: [48/80][100/250]	LR: 0.01	Time 0.033 (0.035)	Data 0.025 (0.024)	Loss 2.3023 (2.3027)	Prec@1 9.000 (9.752)
# Epoch: [48/80][200/250]	LR: 0.01	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3027 (2.3027)	Prec@1 8.500 (9.687)
#  * Training Prec@1 9.640
# Test: [0/50]	Time 0.097 (0.097)	Loss 2.3022 (2.3022)	Prec@1 10.000 (10.000)
#  * Testing Prec@1 10.000
# Epoch: [49/80][0/250]	LR: 0.01	Time 0.230 (0.230)	Data 0.218 (0.218)	Loss 2.3031 (2.3031)	Prec@1 4.500 (4.500)
# Epoch: [49/80][100/250]	LR: 0.01	Time 0.035 (0.038)	Data 0.025 (0.027)	Loss 2.3024 (2.3027)	Prec@1 10.500 (9.649)
# Epoch: [49/80][200/250]	LR: 0.01	Time 0.034 (0.037)	Data 0.023 (0.026)	Loss 2.3032 (2.3027)	Prec@1 6.000 (9.659)
#  * Training Prec@1 9.564
# Test: [0/50]	Time 0.138 (0.138)	Loss 2.3022 (2.3022)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [50/80][0/250]	LR: 0.01	Time 0.267 (0.267)	Data 0.253 (0.253)	Loss 2.3015 (2.3015)	Prec@1 12.000 (12.000)
# Epoch: [50/80][100/250]	LR: 0.01	Time 0.034 (0.036)	Data 0.024 (0.026)	Loss 2.3027 (2.3027)	Prec@1 6.500 (9.822)
# Epoch: [50/80][200/250]	LR: 0.01	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3027 (2.3027)	Prec@1 10.500 (9.776)
#  * Training Prec@1 9.758
# Test: [0/50]	Time 0.128 (0.128)	Loss 2.3023 (2.3023)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [51/80][0/250]	LR: 0.01	Time 0.280 (0.280)	Data 0.263 (0.263)	Loss 2.3023 (2.3023)	Prec@1 7.500 (7.500)
# Epoch: [51/80][100/250]	LR: 0.01	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3036 (2.3027)	Prec@1 7.500 (9.911)
# Epoch: [51/80][200/250]	LR: 0.01	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3020 (2.3028)	Prec@1 16.000 (9.811)
#  * Training Prec@1 9.802
# Test: [0/50]	Time 0.093 (0.093)	Loss 2.3026 (2.3026)	Prec@1 10.500 (10.500)
#  * Testing Prec@1 10.000
# Epoch: [52/80][0/250]	LR: 0.01	Time 0.240 (0.240)	Data 0.229 (0.229)	Loss 2.3028 (2.3028)	Prec@1 8.500 (8.500)
# Epoch: [52/80][100/250]	LR: 0.01	Time 0.031 (0.035)	Data 0.020 (0.025)	Loss 2.3026 (2.3027)	Prec@1 10.500 (10.183)
# Epoch: [52/80][200/250]	LR: 0.01	Time 0.032 (0.034)	Data 0.023 (0.024)	Loss 2.3026 (2.3028)	Prec@1 10.500 (10.060)
#  * Training Prec@1 9.964
# Test: [0/50]	Time 0.103 (0.103)	Loss 2.3024 (2.3024)	Prec@1 10.000 (10.000)
#  * Testing Prec@1 10.000
# Epoch: [53/80][0/250]	LR: 0.01	Time 0.169 (0.169)	Data 0.155 (0.155)	Loss 2.3032 (2.3032)	Prec@1 11.500 (11.500)
# Epoch: [53/80][100/250]	LR: 0.01	Time 0.034 (0.039)	Data 0.024 (0.028)	Loss 2.3033 (2.3028)	Prec@1 7.000 (9.950)
# Epoch: [53/80][200/250]	LR: 0.01	Time 0.034 (0.038)	Data 0.025 (0.028)	Loss 2.3022 (2.3028)	Prec@1 9.500 (9.863)
#  * Training Prec@1 9.834
# Test: [0/50]	Time 0.127 (0.127)	Loss 2.3025 (2.3025)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [54/80][0/250]	LR: 0.01	Time 0.150 (0.150)	Data 0.138 (0.138)	Loss 2.3030 (2.3030)	Prec@1 8.500 (8.500)
# Epoch: [54/80][100/250]	LR: 0.01	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3038 (2.3027)	Prec@1 7.500 (9.990)
# Epoch: [54/80][200/250]	LR: 0.01	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3034 (2.3027)	Prec@1 7.500 (9.836)
#  * Training Prec@1 9.754
# Test: [0/50]	Time 0.095 (0.095)	Loss 2.3033 (2.3033)	Prec@1 7.500 (7.500)
#  * Testing Prec@1 10.000
# Epoch: [55/80][0/250]	LR: 0.01	Time 0.242 (0.242)	Data 0.231 (0.231)	Loss 2.3024 (2.3024)	Prec@1 11.000 (11.000)
# Epoch: [55/80][100/250]	LR: 0.01	Time 0.034 (0.035)	Data 0.024 (0.025)	Loss 2.3018 (2.3027)	Prec@1 9.000 (9.941)
# Epoch: [55/80][200/250]	LR: 0.01	Time 0.035 (0.034)	Data 0.024 (0.023)	Loss 2.3019 (2.3028)	Prec@1 10.000 (9.674)
#  * Training Prec@1 9.622
# Test: [0/50]	Time 0.126 (0.126)	Loss 2.3025 (2.3025)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [56/80][0/250]	LR: 0.01	Time 0.149 (0.149)	Data 0.135 (0.135)	Loss 2.3027 (2.3027)	Prec@1 7.000 (7.000)
# Epoch: [56/80][100/250]	LR: 0.01	Time 0.035 (0.037)	Data 0.025 (0.027)	Loss 2.3036 (2.3027)	Prec@1 8.000 (9.970)
# Epoch: [56/80][200/250]	LR: 0.01	Time 0.034 (0.036)	Data 0.023 (0.025)	Loss 2.3031 (2.3027)	Prec@1 11.000 (9.873)
#  * Training Prec@1 9.870
# Test: [0/50]	Time 0.132 (0.132)	Loss 2.3013 (2.3013)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [57/80][0/250]	LR: 0.01	Time 0.265 (0.265)	Data 0.250 (0.250)	Loss 2.3032 (2.3032)	Prec@1 11.000 (11.000)
# Epoch: [57/80][100/250]	LR: 0.01	Time 0.032 (0.036)	Data 0.022 (0.026)	Loss 2.3011 (2.3027)	Prec@1 13.500 (9.980)
# Epoch: [57/80][200/250]	LR: 0.01	Time 0.033 (0.034)	Data 0.023 (0.025)	Loss 2.3031 (2.3027)	Prec@1 9.000 (9.811)
#  * Training Prec@1 9.816
# Test: [0/50]	Time 0.127 (0.127)	Loss 2.3032 (2.3032)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [58/80][0/250]	LR: 0.01	Time 0.259 (0.259)	Data 0.248 (0.248)	Loss 2.3025 (2.3025)	Prec@1 11.000 (11.000)
# Epoch: [58/80][100/250]	LR: 0.01	Time 0.034 (0.038)	Data 0.024 (0.027)	Loss 2.3026 (2.3027)	Prec@1 10.500 (9.812)
# Epoch: [58/80][200/250]	LR: 0.01	Time 0.032 (0.035)	Data 0.022 (0.025)	Loss 2.3026 (2.3028)	Prec@1 10.500 (9.749)
#  * Training Prec@1 9.810
# Test: [0/50]	Time 0.095 (0.095)	Loss 2.3030 (2.3030)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [59/80][0/250]	LR: 0.01	Time 0.282 (0.282)	Data 0.266 (0.266)	Loss 2.3031 (2.3031)	Prec@1 12.500 (12.500)
# Epoch: [59/80][100/250]	LR: 0.01	Time 0.032 (0.038)	Data 0.023 (0.028)	Loss 2.3023 (2.3027)	Prec@1 10.000 (9.698)
# Epoch: [59/80][200/250]	LR: 0.01	Time 0.031 (0.036)	Data 0.021 (0.025)	Loss 2.3025 (2.3027)	Prec@1 9.500 (9.841)
#  * Training Prec@1 9.754
# Test: [0/50]	Time 0.135 (0.135)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [60/80][0/250]	LR: 0.001	Time 0.185 (0.185)	Data 0.170 (0.170)	Loss 2.3024 (2.3024)	Prec@1 9.500 (9.500)
# Epoch: [60/80][100/250]	LR: 0.001	Time 0.033 (0.034)	Data 0.024 (0.024)	Loss 2.3024 (2.3026)	Prec@1 11.500 (10.035)
# Epoch: [60/80][200/250]	LR: 0.001	Time 0.032 (0.034)	Data 0.021 (0.024)	Loss 2.3025 (2.3026)	Prec@1 7.500 (9.968)
#  * Training Prec@1 9.936
# Test: [0/50]	Time 0.101 (0.101)	Loss 2.3025 (2.3025)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [61/80][0/250]	LR: 0.001	Time 0.238 (0.238)	Data 0.223 (0.223)	Loss 2.3027 (2.3027)	Prec@1 7.500 (7.500)
# Epoch: [61/80][100/250]	LR: 0.001	Time 0.035 (0.036)	Data 0.025 (0.026)	Loss 2.3025 (2.3026)	Prec@1 12.500 (9.733)
# Epoch: [61/80][200/250]	LR: 0.001	Time 0.052 (0.035)	Data 0.041 (0.025)	Loss 2.3029 (2.3026)	Prec@1 10.500 (9.637)
#  * Training Prec@1 9.642
# Test: [0/50]	Time 0.139 (0.139)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [62/80][0/250]	LR: 0.001	Time 0.168 (0.168)	Data 0.153 (0.153)	Loss 2.3023 (2.3023)	Prec@1 8.500 (8.500)
# Epoch: [62/80][100/250]	LR: 0.001	Time 0.033 (0.039)	Data 0.022 (0.028)	Loss 2.3026 (2.3026)	Prec@1 9.000 (9.970)
# Epoch: [62/80][200/250]	LR: 0.001	Time 0.033 (0.036)	Data 0.022 (0.025)	Loss 2.3029 (2.3026)	Prec@1 9.500 (10.100)
#  * Training Prec@1 10.000
# Test: [0/50]	Time 0.133 (0.133)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [63/80][0/250]	LR: 0.001	Time 0.267 (0.267)	Data 0.252 (0.252)	Loss 2.3027 (2.3027)	Prec@1 7.500 (7.500)
# Epoch: [63/80][100/250]	LR: 0.001	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3026 (2.3026)	Prec@1 11.000 (10.015)
# Epoch: [63/80][200/250]	LR: 0.001	Time 0.032 (0.034)	Data 0.023 (0.024)	Loss 2.3022 (2.3026)	Prec@1 12.000 (9.920)
#  * Training Prec@1 9.906
# Test: [0/50]	Time 0.096 (0.096)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [64/80][0/250]	LR: 0.001	Time 0.230 (0.230)	Data 0.219 (0.219)	Loss 2.3023 (2.3023)	Prec@1 10.000 (10.000)
# Epoch: [64/80][100/250]	LR: 0.001	Time 0.035 (0.035)	Data 0.024 (0.024)	Loss 2.3026 (2.3026)	Prec@1 8.500 (10.173)
# Epoch: [64/80][200/250]	LR: 0.001	Time 0.033 (0.034)	Data 0.022 (0.023)	Loss 2.3026 (2.3026)	Prec@1 13.000 (9.871)
#  * Training Prec@1 9.864
# Test: [0/50]	Time 0.143 (0.143)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [65/80][0/250]	LR: 0.001	Time 0.161 (0.161)	Data 0.146 (0.146)	Loss 2.3028 (2.3028)	Prec@1 10.500 (10.500)
# Epoch: [65/80][100/250]	LR: 0.001	Time 0.033 (0.034)	Data 0.023 (0.024)	Loss 2.3026 (2.3026)	Prec@1 8.000 (9.767)
# Epoch: [65/80][200/250]	LR: 0.001	Time 0.034 (0.036)	Data 0.024 (0.025)	Loss 2.3025 (2.3026)	Prec@1 9.500 (9.799)
#  * Training Prec@1 9.754
# Test: [0/50]	Time 0.139 (0.139)	Loss 2.3026 (2.3026)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [66/80][0/250]	LR: 0.001	Time 0.256 (0.256)	Data 0.241 (0.241)	Loss 2.3026 (2.3026)	Prec@1 6.500 (6.500)
# Epoch: [66/80][100/250]	LR: 0.001	Time 0.045 (0.040)	Data 0.034 (0.029)	Loss 2.3027 (2.3026)	Prec@1 7.000 (9.891)
# Epoch: [66/80][200/250]	LR: 0.001	Time 0.045 (0.038)	Data 0.034 (0.028)	Loss 2.3028 (2.3026)	Prec@1 11.500 (9.891)
#  * Training Prec@1 9.870
# Test: [0/50]	Time 0.142 (0.142)	Loss 2.3025 (2.3025)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [67/80][0/250]	LR: 0.001	Time 0.157 (0.157)	Data 0.142 (0.142)	Loss 2.3026 (2.3026)	Prec@1 9.000 (9.000)
# Epoch: [67/80][100/250]	LR: 0.001	Time 0.030 (0.035)	Data 0.020 (0.024)	Loss 2.3024 (2.3026)	Prec@1 14.000 (9.649)
# Epoch: [67/80][200/250]	LR: 0.001	Time 0.044 (0.035)	Data 0.033 (0.024)	Loss 2.3027 (2.3026)	Prec@1 11.500 (9.701)
#  * Training Prec@1 9.696
# Test: [0/50]	Time 0.122 (0.122)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [68/80][0/250]	LR: 0.001	Time 0.264 (0.264)	Data 0.248 (0.248)	Loss 2.3026 (2.3026)	Prec@1 10.000 (10.000)
# Epoch: [68/80][100/250]	LR: 0.001	Time 0.035 (0.036)	Data 0.023 (0.026)	Loss 2.3027 (2.3026)	Prec@1 10.000 (10.079)
# Epoch: [68/80][200/250]	LR: 0.001	Time 0.035 (0.035)	Data 0.025 (0.025)	Loss 2.3025 (2.3026)	Prec@1 10.000 (9.958)
#  * Training Prec@1 9.844
# Test: [0/50]	Time 0.130 (0.130)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [69/80][0/250]	LR: 0.001	Time 0.289 (0.289)	Data 0.269 (0.269)	Loss 2.3026 (2.3026)	Prec@1 7.500 (7.500)
# Epoch: [69/80][100/250]	LR: 0.001	Time 0.035 (0.036)	Data 0.025 (0.026)	Loss 2.3026 (2.3026)	Prec@1 12.000 (10.144)
# Epoch: [69/80][200/250]	LR: 0.001	Time 0.032 (0.035)	Data 0.021 (0.024)	Loss 2.3026 (2.3026)	Prec@1 10.000 (9.915)
#  * Training Prec@1 9.806
# Test: [0/50]	Time 0.110 (0.110)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [70/80][0/250]	LR: 0.001	Time 0.243 (0.243)	Data 0.230 (0.230)	Loss 2.3026 (2.3026)	Prec@1 10.500 (10.500)
# Epoch: [70/80][100/250]	LR: 0.001	Time 0.033 (0.040)	Data 0.023 (0.029)	Loss 2.3027 (2.3026)	Prec@1 10.000 (9.678)
# Epoch: [70/80][200/250]	LR: 0.001	Time 0.036 (0.036)	Data 0.026 (0.026)	Loss 2.3026 (2.3026)	Prec@1 8.500 (9.821)
#  * Training Prec@1 9.680
# Test: [0/50]	Time 0.126 (0.126)	Loss 2.3025 (2.3025)	Prec@1 14.000 (14.000)
#  * Testing Prec@1 10.000
# Epoch: [71/80][0/250]	LR: 0.001	Time 0.216 (0.216)	Data 0.204 (0.204)	Loss 2.3027 (2.3027)	Prec@1 7.000 (7.000)
# Epoch: [71/80][100/250]	LR: 0.001	Time 0.032 (0.038)	Data 0.022 (0.028)	Loss 2.3027 (2.3026)	Prec@1 12.500 (9.886)
# Epoch: [71/80][200/250]	LR: 0.001	Time 0.033 (0.037)	Data 0.021 (0.026)	Loss 2.3025 (2.3026)	Prec@1 11.500 (9.687)
#  * Training Prec@1 9.634
# Test: [0/50]	Time 0.146 (0.146)	Loss 2.3026 (2.3026)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [72/80][0/250]	LR: 0.001	Time 0.164 (0.164)	Data 0.149 (0.149)	Loss 2.3026 (2.3026)	Prec@1 9.000 (9.000)
# Epoch: [72/80][100/250]	LR: 0.001	Time 0.032 (0.036)	Data 0.022 (0.025)	Loss 2.3026 (2.3026)	Prec@1 10.500 (9.901)
# Epoch: [72/80][200/250]	LR: 0.001	Time 0.033 (0.035)	Data 0.023 (0.024)	Loss 2.3025 (2.3026)	Prec@1 10.500 (9.716)
#  * Training Prec@1 9.672
# Test: [0/50]	Time 0.133 (0.133)	Loss 2.3026 (2.3026)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [73/80][0/250]	LR: 0.001	Time 0.242 (0.242)	Data 0.230 (0.230)	Loss 2.3025 (2.3025)	Prec@1 13.000 (13.000)
# Epoch: [73/80][100/250]	LR: 0.001	Time 0.043 (0.040)	Data 0.032 (0.029)	Loss 2.3026 (2.3026)	Prec@1 9.000 (9.881)
# Epoch: [73/80][200/250]	LR: 0.001	Time 0.046 (0.038)	Data 0.034 (0.028)	Loss 2.3025 (2.3026)	Prec@1 14.000 (9.920)
#  * Training Prec@1 9.822
# Test: [0/50]	Time 0.136 (0.136)	Loss 2.3025 (2.3025)	Prec@1 13.000 (13.000)
#  * Testing Prec@1 10.000
# Epoch: [74/80][0/250]	LR: 0.001	Time 0.154 (0.154)	Data 0.139 (0.139)	Loss 2.3026 (2.3026)	Prec@1 10.000 (10.000)
# Epoch: [74/80][100/250]	LR: 0.001	Time 0.036 (0.035)	Data 0.027 (0.024)	Loss 2.3026 (2.3026)	Prec@1 9.500 (10.332)
# Epoch: [74/80][200/250]	LR: 0.001	Time 0.033 (0.034)	Data 0.025 (0.024)	Loss 2.3027 (2.3026)	Prec@1 9.000 (10.045)
#  * Training Prec@1 9.866
# Test: [0/50]	Time 0.105 (0.105)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [75/80][0/250]	LR: 0.001	Time 0.117 (0.117)	Data 0.105 (0.105)	Loss 2.3026 (2.3026)	Prec@1 10.000 (10.000)
# Epoch: [75/80][100/250]	LR: 0.001	Time 0.034 (0.034)	Data 0.025 (0.025)	Loss 2.3026 (2.3026)	Prec@1 13.000 (9.861)
# Epoch: [75/80][200/250]	LR: 0.001	Time 0.033 (0.034)	Data 0.022 (0.024)	Loss 2.3026 (2.3026)	Prec@1 11.500 (9.726)
#  * Training Prec@1 9.650
# Test: [0/50]	Time 0.122 (0.122)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
#  * Testing Prec@1 10.000
# Epoch: [76/80][0/250]	LR: 0.001	Time 0.269 (0.269)	Data 0.254 (0.254)	Loss 2.3026 (2.3026)	Prec@1 8.000 (8.000)
# Epoch: [76/80][100/250]	LR: 0.001	Time 0.035 (0.041)	Data 0.022 (0.030)	Loss 2.3025 (2.3026)	Prec@1 14.000 (9.837)
# Epoch: [76/80][200/250]	LR: 0.001	Time 0.036 (0.037)	Data 0.025 (0.027)	Loss 2.3026 (2.3026)	Prec@1 11.500 (9.781)
#  * Training Prec@1 9.680
# Test: [0/50]	Time 0.167 (0.167)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [77/80][0/250]	LR: 0.001	Time 0.228 (0.228)	Data 0.212 (0.212)	Loss 2.3026 (2.3026)	Prec@1 6.000 (6.000)
# Epoch: [77/80][100/250]	LR: 0.001	Time 0.034 (0.038)	Data 0.025 (0.028)	Loss 2.3026 (2.3026)	Prec@1 10.500 (9.525)
# Epoch: [77/80][200/250]	LR: 0.001	Time 0.034 (0.038)	Data 0.024 (0.027)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.654)
#  * Training Prec@1 9.606
# Test: [0/50]	Time 0.131 (0.131)	Loss 2.3026 (2.3026)	Prec@1 9.000 (9.000)
#  * Testing Prec@1 10.000
# Epoch: [78/80][0/250]	LR: 0.001	Time 0.256 (0.256)	Data 0.241 (0.241)	Loss 2.3026 (2.3026)	Prec@1 10.000 (10.000)
# Epoch: [78/80][100/250]	LR: 0.001	Time 0.033 (0.036)	Data 0.022 (0.025)	Loss 2.3027 (2.3026)	Prec@1 10.500 (9.683)
# Epoch: [78/80][200/250]	LR: 0.001	Time 0.033 (0.035)	Data 0.022 (0.025)	Loss 2.3027 (2.3026)	Prec@1 9.000 (9.699)
#  * Training Prec@1 9.638
# Test: [0/50]	Time 0.103 (0.103)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000
# Epoch: [79/80][0/250]	LR: 0.001	Time 0.228 (0.228)	Data 0.214 (0.214)	Loss 2.3026 (2.3026)	Prec@1 9.500 (9.500)
# Epoch: [79/80][100/250]	LR: 0.001	Time 0.033 (0.035)	Data 0.023 (0.025)	Loss 2.3027 (2.3026)	Prec@1 7.000 (10.040)
# Epoch: [79/80][200/250]	LR: 0.001	Time 0.032 (0.034)	Data 0.022 (0.024)	Loss 2.3027 (2.3026)	Prec@1 8.000 (9.833)
#  * Training Prec@1 9.744
# Test: [0/50]	Time 0.102 (0.102)	Loss 2.3026 (2.3026)	Prec@1 7.000 (7.000)
#  * Testing Prec@1 10.000

# %% [markdown]
# ### Plot of PlainNoBnNet20

# %%
train_noBN, test_noBN, _, _ = plot('log_plain20_noBN.txt')

# %% [markdown]
# ### Plot of PlainNet20

# %%
train, test, _, _ = plot('log_plain20.txt')

# %% [markdown]
# - We can see it's so obvious that without BN, PlainNoBnNet20 barely learns anything with learning rate = 0.1. Maybe use smaller learning rate will give us some result.
# - Batch normalization narrows valleys in the cost function, allows us to use higher learning rate and improves the accuracy when network is deep and features are unbalanced.
